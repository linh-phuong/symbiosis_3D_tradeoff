# %%
import numpy as np
import matplotlib.pylab as plt
from tools import Config, turn_raw_dat_to_sorted_arrays
from tools_evo_dyn import tau_leap_symbiosis_mutation
import pickle

# %%
cg_evo_1 =  Config(dict(eta = 4.12, g = 1.312, mu = 1.4, alpha = 1.2, gamma = 1.23, p = 0.1, beta = 2.1,
                        r = 2.3, d = 1.3, theta = 8., v = 4.52, h = 0.382, nu_max = 3))

# %%
np.random.seed(1234)
V = 200
init = np.array([7.1, 5., 3.2])
ds_1 = tau_leap_symbiosis_mutation(pop_init = init * V, Tmax = 5000000, dt = 1, cg = cg_evo_1, V = V, 
                                         trait_init = np.array([2, -0.5]), sigma_rho = 0.1, sigma_nu = 0.1, 
                                         mutant_rate = 0.001, step = 5000)
# Out:
# /Users/phuongnguyen/Work/symbiosis_3D_tradeoff/tools_evo_dyn.py:8: RuntimeWarning: invalid value encountered in power
#   return cg.theta - cg.v * rho**cg.h + (cg.eta * nu * (nu + cg.d) ** cg.g) / cg.nu_max

# %%
with open("data_evol_traject/ds1_scenario3_exp.pkl", "wb") as f:
    pickle.dump(ds_1, f)

# %%
np.random.seed(123)
V = 200
init = np.array([17.1, 15., 14.2])
ds_2 = tau_leap_symbiosis_mutation(pop_init = init * V, Tmax = 4000000, dt = 1, cg = cg_evo_1, V = V, 
                                         trait_init = np.array([2, 0]), sigma_rho = 0.1, sigma_nu = 0.1, 
                                         mutant_rate = 0.001, step = 4000)
# Out:
# Simulation stop at time step 3011499 as total Fs = 279.0, total As = 6.0, Hs = 0.0

# %%
with open("data_evol_traject/ds2_scenario3_exp.pkl", "wb") as f:
    pickle.dump(ds_2, f)

# %%
np.random.seed(1928)
V = 200
init = np.array([20.1, 11., 10.2])
ds_3 = tau_leap_symbiosis_mutation(pop_init = init * V, Tmax = 3000000, dt = 1, cg = cg_evo_1, V = V, 
                                         trait_init = np.array([1, 0.]), sigma_rho = 0.1, sigma_nu = 0.1, 
                                         mutant_rate = 0.001, step = 3000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 4
#       2 V = 200
#       3 init = np.array([20.1, 11., 10.2])
# ----> 4 ds_3 = tau_leap_symbiosis_mutation(pop_init = init * V, Tmax = 3000000, dt = 1, cg = cg_evo_1, V = V,
#       5                                          trait_init = np.array([1, 0.]), sigma_rho = 0.1, sigma_nu = 0.1,
#       6                                          mutant_rate = 0.001, step = 300)
#
# File ~/Work/symbiosis_3D_tradeoff/tools_evo_dyn.py:82, in tau_leap_symbiosis_mutation(pop_init, Tmax, dt, cg, V, trait_init, sigma_rho, sigma_nu, mutant_rate, step)
#      80 dr = A_death_mut(Fs, As, Hs, cg, V, nus)  # rate
#      81 A_change = poisson(br * dt) - poisson(dr * dt)  # intergers
# ---> 82 br = H_birth_mut(As, Hs, cg, V)  # rate
#      83 dr = H_death_mut(Fs, As, Hs, cg, V)  # rate
# ...

# %%
with open("data_evol_traject/ds3_scenario3_exp.pkl", "wb") as f:
    pickle.dump(ds_3, f)

# %%
np.random.seed(2)
V = 200
init = np.array([15.1, 5., 1.2])
ds_4 = tau_leap_symbiosis_mutation(pop_init = init * V, Tmax = 3000000, dt = 1, cg = cg_evo_1, V = V, 
                                         trait_init = np.array([1, 0.1]), sigma_rho = 0.1, sigma_nu = 0.1, 
                                         mutant_rate = 0.001, step = 3000)
# Out:
# Simulation stop at time step 2152480 as total Fs = 123.0, total As = 6.0, Hs = 0.0

# %%
with open("data_evol_traject/ds4_scenario3_exp.pkl", "wb") as f:
    pickle.dump(ds_4, f)
